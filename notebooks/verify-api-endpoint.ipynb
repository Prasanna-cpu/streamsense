# %%
import requests
base_url = "http://localhost:8000"

# %%
endpoint = "/api/events/create"
# base_url = "http://localhost:8000"

url = f"{base_url}{endpoint}"

response = requests.post(url, json={"page" : "page8", "description" : "description-8"})
print(response.json())
print(response.ok)
# Out:
# {'description': 'description-8', 'updated_at': '2026-07-03T11:25:34.926596Z', 'created_at': '2026-07-03T11:25:34.926581Z', 'id': 1, 'page': 'page8'}
# True

# %%
endpoint = "/api/events/"
url = f"{base_url}{endpoint}"
response = requests.get(url)
print(response.json())
print(response.ok)
# Out:
# {'results': [{'page': 'page4', 'description': 'description4', 'id': 1, 'created_at': '2026-07-03T08:08:29.329635Z'}], 'count': 1}
# True

# %%
endpoint = "/api/events/1"
url = f"{base_url}{endpoint}"
response = requests.get(url)
print(response.json())
print(response.ok)
# Out:
# {'page': 'page4', 'description': 'description4', 'id': 1, 'created_at': '2026-07-03T08:08:29.329635Z'}
# True

# %%
endpoint="/api/events/update/1"
url = f"{base_url}{endpoint}"
response = requests.put(url, json={"description" : "description 9028 is good"})
print(response.json())
print(response.ok)
# Out:
# {'description': 'description 9028 is good', 'updated_at': '2026-07-03T11:26:21.940787Z', 'created_at': '2026-07-03T11:25:34.926581Z', 'id': 1, 'page': 'page8'}
# True
